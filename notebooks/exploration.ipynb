# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve().parents[0]
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print("[DEBUG] Project root added to sys.path:", project_root)

# %%
from query_helper import run_query

query="""
SELECT *
FROM air_pollution_data;
"""
run_query(query)
# Out:
# [DEBUG] Using DB at: /Users/robertoberrocal/datahub-api/data/datahub.db
# [DEBUG] Query executed successfully. Rows returned: 360
#           city  aqi      co    no    no2     o3   so2  pm2_5   pm10   nh3  \
# 0       Berlin    1  165.98  0.01  15.57  27.88  0.49   5.89   7.86  1.79
# 1       Berlin    1  170.04  0.02  16.22  26.05  0.50   6.50   8.51  1.82
# 2       Berlin    1  178.87  0.05  18.30  23.14  0.61   7.28   9.34  1.88
# 3       Berlin    1  189.53  0.31  21.50  19.09  0.74   7.98  10.09  1.95
# 4       Berlin    1  197.64  2.68  20.95  19.12  0.90   8.40  10.60  2.20
# ..         ...  ...     ...   ...    ...    ...   ...    ...    ...   ...
# 355  Frankfurt    2  315.03  2.70  31.88  17.89  2.68  16.17  19.74  2.59
# 356  Frankfurt    2  313.03  1.83  31.74  16.49  2.14  17.03  20.27  2.45
# 357  Frankfurt    2  307.06  1.14  30.58  17.16  1.78  17.75  20.72  2.29
# 358  Frankfurt    2  302.67  0.83  29.30  18.60  1.55  18.26  20.99  2.23
# 359  Frankfurt    2  297.70  0.67  28.01  20.40  1.43  18.73  21.31  2.21
#
#                            date
# 0    2025-10-31 04:00:00.000000
# 1    2025-10-31 05:00:00.000000
# 2    2025-10-31 06:00:00.000000
# 3    2025-10-31 07:00:00.000000
# 4    2025-10-31 08:00:00.000000
# ..                          ...
# 355  2025-11-04 23:00:00.000000
# 356  2025-11-05 00:00:00.000000
# 357  2025-11-05 01:00:00.000000
# 358  2025-11-05 02:00:00.000000
# 359  2025-11-05 03:00:00.000000
#
# [360 rows x 11 columns]
